# %%
using Pkg
Pkg.add("DifferentialEquations")
# Out:
#   Updating registry at `~/.julia/registries/General`
#   Updating git-repo `https://github.com/JuliaRegistries/General.git`
#  Resolving package versions...
#   Updating `~/.julia/environments/v1.1/Project.toml`
#  [no changes]
#   Updating `~/.julia/environments/v1.1/Manifest.toml`
#  [no changes]

# %%
IJulia.include("using_packages.jl")
# Out:
# ┌ Warning: Package IJulia does not have DifferentialEquations in its dependencies:
# │ - If you have IJulia checked out for development and have
# │   added DifferentialEquations as a dependency but haven't updated your primary
# │   environment's manifest file, try `Pkg.resolve()`.
# │ - Otherwise you may need to report an issue with IJulia
# │ Loading DifferentialEquations into IJulia from project dependency, future warnings for IJulia are suppressed.
# └ @ nothing nothing:840

# %%
IJulia.include("floudas_problems.jl")

# %%
IJulia.include("objective_functions.jl")
# Out:
# soft_l1 (generic function with 1 method)

# %%
IJulia.load("floudas_problems.jl")

# %%
# No Noise
IJulia.include("random_or_heuristic.jl")
# Out:
# ┌ Warning: Linesearch failed, using alpha = 0.27700599993374475 and exiting optimization.
# │ The linesearch exited with message:
# │ Linesearch failed to converge, reached maximum iterations 50.
# └ @ Optim /home/andrew/.julia/packages/Optim/ULNLZ/src/utilities/perform_linesearch.jl:47
# ┌ Warning: Linesearch failed, using alpha = 0.7165251391112906 and exiting optimization.
# │ The linesearch exited with message:
# │ Linesearch failed to converge, reached maximum iterations 50.
# └ @ Optim /home/andrew/.julia/packages/Optim/ULNLZ/src/utilities/perform_linesearch.jl:47
# ┌ Warning: Linesearch failed, using alpha = 0.658372513647995 and exiting optimization.
# │ The linesearch exited with message:
# │ Linesearch failed to converge, reached maximum iterations 50.
# └ @ Optim /home/andrew/.julia/packages/Optim/ULNLZ/src/utilities/perform_linesearch.jl:47
# ┌ Warning: Linesearch failed, using alpha = 0.25486670267209305 and exiting optimization.
# │ The linesearch exited with message:
# ...

# %%
# Floudas' Dataset
IJulia.include("random_or_heuristic.jl")
# Out:
# ┌ Warning: Linesearch failed, using alpha = 0.5535120091785066 and exiting optimization.
# │ The linesearch exited with message:
# │ Linesearch failed to converge, reached maximum iterations 50.
# └ @ Optim /home/andrew/.julia/packages/Optim/ULNLZ/src/utilities/perform_linesearch.jl:47
# ┌ Warning: Linesearch failed, using alpha = 4.4342449270295505 and exiting optimization.
# │ The linesearch exited with message:
# │ Linesearch failed to converge, reached maximum iterations 50.
# └ @ Optim /home/andrew/.julia/packages/Optim/ULNLZ/src/utilities/perform_linesearch.jl:47
# ┌ Warning: Linesearch failed, using alpha = 2.1201781590817427e-14 and exiting optimization.
# │ The linesearch exited with message:
# │ Linesearch failed to converge, reached maximum iterations 50.
# └ @ Optim /home/andrew/.julia/packages/Optim/ULNLZ/src/utilities/perform_linesearch.jl:47

# %%
# 10% Noise
IJulia.include("random_or_heuristic.jl")

# %%
# No Noise
IJulia.include("random_or_heuristic.jl")
# Out:
# ----- Getting results for Flouda's Problem number 1 -----
#
# --- Iteration 1---
#
# --- Iteration 2---
#
# --- Iteration 3---
#
# --- Iteration 4---
#
# --- Iteration 5---
#
# --- Iteration 6---
#
# --- Iteration 7---
#
# --- Iteration 8---
#
# --- Iteration 9---
#
# --- Iteration 10---
#
# --- Iteration 11---
#
# --- Iteration 12---
#
# --- Iteration 13---
#
# --- Iteration 14---
#
# --- Iteration 15---
#
# --- Iteration 16---
#
# --- Iteration 17---
#
# --- Iteration 18---
#
# --- Iteration 19---
#
# --- Iteration 20---
#
# --- Iteration 21---
#
# --- Iteration 22---
#
# --- Iteration 23---
#
# --- Iteration 24---
#
# --- Iteration 25---
#
# --- Iteration 26---
#
# --- Iteration 27---
#
# --- Iteration 28---
#
# --- Iteration 29---
# --- Iteration 30---
#
# ----- Getting results for Flouda's Problem number 2 -----
#
# --- Iteration 1---
#
# --- Iteration 2---
#
# --- Iteration 3---
#
# --- Iteration 4---
#
# --- Iteration 5---
#
# --- Iteration 6---
#
# --- Iteration 7---
#
# ...

# %%
# Floudas' Dataset
IJulia.include("random_or_heuristic.jl")
# Out:
# ----- Getting results for Flouda's Problem number 1 -----
#
# --- Iteration 1---
#
# --- Iteration 2---
#
# --- Iteration 3---
#
# --- Iteration 4---
#
# --- Iteration 5---
#
# --- Iteration 6---
#
# --- Iteration 7---
#
# --- Iteration 8---
#
# --- Iteration 9---
#
# --- Iteration 10---
#
# --- Iteration 11---
#
# --- Iteration 12---
#
# --- Iteration 13---
#
# --- Iteration 14---
#
# --- Iteration 15---
#
# --- Iteration 16---
#
# --- Iteration 17---
#
# --- Iteration 18---
#
# --- Iteration 19---
#
# --- Iteration 20---
#
# --- Iteration 21---
#
# --- Iteration 22---
#
# --- Iteration 23---
#
# --- Iteration 24---
#
# --- Iteration 25---
#
# --- Iteration 26---
#
# --- Iteration 27---
#
# --- Iteration 28---
#
# --- Iteration 29---
# --- Iteration 30---
#
# ----- Getting results for Flouda's Problem number 2 -----
#
# --- Iteration 1---
#
# --- Iteration 2---
#
# --- Iteration 3---
#
# --- Iteration 4---
#
# --- Iteration 5---
#
# --- Iteration 6---
#
# --- Iteration 7---
#
# ...

# %%
old = precision(BigFloat)
# Out:
# 256
